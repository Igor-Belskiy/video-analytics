# %% [markdown]
# <a href="https://colab.research.google.com/github/Igor-Belskiy/video-analytics/blob/main/OpenCV_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-contrib-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install caer
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 809 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 15.3 MB 53.3 MB/s
# ...
#      |████████████████████████████████| 843 kB 53.5 MB/s
# ...

# %%
import cv2 as cv

# %%
# Загружаем с гугл-драйва картинку с котом

from google_drive_downloader import GoogleDriveDownloader as gdd   
gdd.download_file_from_google_drive(file_id='1ouWgdKojJ3hmF7v8_hWrjqssreXpn_GG', 
                                    dest_path='/content/cat.jpg', 
                                    showsize=True,
                                    overwrite=True)
# Out:
# ...
# 672.0 KiB Done.

# %%
img = cv.imread('/content/cat.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
from PIL import Image #Для отрисовки изображений

Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080 at 0x7F1170747310>

# %%
# Загружаем с гугл-диска в колабораторию видео с котами

gdd.download_file_from_google_drive(file_id='1CJh74Ty2nSPFCqTa6BEpT5eBE4OPMArX', 
                                    dest_path='/content/hermitage cats.mp4', 
                                    showsize=True,
                                    overwrite=True)
# Out:
# ...
# 18.1 MiB Done.

# %%
capture = cv.VideoCapture('/content/hermitage cats.mp4')

# %%
type(capture)
# Out:
# cv2.VideoCapture

# %%
while True:
  isTrue, frame = capture.read()
# Out:
# (True, array([[[ 10,  25,  34],
#          [ 10,  25,  34],
#          [ 10,  25,  34],
#          ...,
#          [ 75,  69,  72],
#          [ 73,  67,  70],
#          [ 47,  41,  44]],
#
#         [[ 10,  25,  34],
#          [ 10,  25,  34],
#          [ 10,  25,  34],
#          ...,
#          [ 75,  69,  72],
#          [ 73,  67,  70],
#          [ 47,  41,  44]],
#
#         [[ 10,  25,  34],
#          [ 10,  25,  34],
#          [ 10,  25,  34],
#          ...,
#          [ 75,  69,  72],
#          [ 73,  67,  70],
#          [ 47,  41,  44]],
#
#         ...,
#
#         [[  5,  22,  38],
#          [  5,  22,  38],
#          [  5,  22,  38],
#          ...,
#          [108,  93,  96],
#          [109,  94,  97],
#          [ 63,  48,  51]],
#
#         [[  5,  22,  38],
#          [  5,  22,  38],
#          [  5,  22,  38],
#          ...,
#          [108,  93,  96],
#          [109,  94,  97],
#          [ 63,  48,  51]],
#
#         [[  5,  22,  38],
# ...
